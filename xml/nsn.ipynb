# %%
import pandas as pd

# %%
df_lib = pd.read_xml('lib.xml',xpath='/lib')

# %%
df_lib
# Out:
#                                            name     date  corner
# 0  tcbn03_bwph169l3p45cpd_basec_lvt_c211022_lib  c211022     NaN

# %%
df_cor = pd.read_xml('lib.xml',xpath='/lib/corner')
df_cor
# Out:
#                                name      P       V     T  view
# 0  ffgnp_0p715v_125c_cbest_CCbest_T  ffgnp  0.715v  125c   NaN

# %%
df_view = pd.read_xml('lib.xml',xpath='/lib/corner/view')
df_view
# Out:
#       name  cell
# 0      CAP   NaN
# 1  CURRENT   NaN
# 2      PWC   NaN

# %%
df_view2 = pd.read_xml('lib.xml',xpath='//view')
df_view2
# Out:
#       name  cell
# 0      CAP   NaN
# 1  CURRENT   NaN
# 2      PWC   NaN

# %%
df_cell = pd.read_xml('lib.xml',xpath='/lib/corner/view/cell')
df_cell
# Out:
#                                    name  type  pin
# 0          AN8ITLICMD1BWP169H3P45CPDLVT  None  NaN
# 1          AN8ITLICMD2BWP169H3P45CPDLVT  None  NaN
# 2   AOI22RPEQAITLICMD1BWP169H3P45CPDLVT  None  NaN
# 3   AOI22RPEQBITLICMD1BWP169H3P45CPDLVT  None  NaN
# 4   AOI22RPEQCITLICMD1BWP169H3P45CPDLVT  None  NaN
# ..                                  ...   ...  ...
# 61      ND4EQBITLICMD2BWP169H3P45CPDLVT  None  NaN
# 62      ND4EQCITLICMD2BWP169H3P45CPDLVT  None  NaN
# 63      ND4EQDITLICMD2BWP169H3P45CPDLVT  None  NaN
# 64         OR8ITLICMD1BWP169H3P45CPDLVT  None  NaN
# 65         OR8ITLICMD2BWP169H3P45CPDLVT  None  NaN
#
# [66 rows x 3 columns]

# %%
df_cell2 = pd.read_xml('lib.xml',xpath='//cell')
df_cell2
# Out:
#                                    name  type  pin
# 0          AN8ITLICMD1BWP169H3P45CPDLVT  None  NaN
# 1          AN8ITLICMD2BWP169H3P45CPDLVT  None  NaN
# 2   AOI22RPEQAITLICMD1BWP169H3P45CPDLVT  None  NaN
# 3   AOI22RPEQBITLICMD1BWP169H3P45CPDLVT  None  NaN
# 4   AOI22RPEQCITLICMD1BWP169H3P45CPDLVT  None  NaN
# ..                                  ...   ...  ...
# 61      ND4EQBITLICMD2BWP169H3P45CPDLVT  None  NaN
# 62      ND4EQCITLICMD2BWP169H3P45CPDLVT  None  NaN
# 63      ND4EQDITLICMD2BWP169H3P45CPDLVT  None  NaN
# 64         OR8ITLICMD1BWP169H3P45CPDLVT  None  NaN
# 65         OR8ITLICMD2BWP169H3P45CPDLVT  None  NaN
#
# [66 rows x 3 columns]

# %%
df_pin = pd.read_xml('lib.xml',xpath='/lib/corner/view/cell/pin')
df_pin
# Out:
#       name  voltage                          vector active_input active_ouput  \
# 0      VDD   0.7150         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 1      VPP   0.7150         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 2      VSS   0.0000         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 3      VBB   0.0000         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 4      VDD   0.7150         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# ...    ...      ...                             ...          ...          ...
# 82691  VSS   0.0000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
# 82692  VDD   0.7865  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
# 82693  VSS   0.0000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
# 82694  VDD   0.7865  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
# 82695  VSS   0.0000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
#
#        state  C1  C2   R  Slew1  Slew2
# 0        NaN NaN NaN NaN    NaN    NaN
# 1        NaN NaN NaN NaN    NaN    NaN
# 2        NaN NaN NaN NaN    NaN    NaN
# 3        NaN NaN NaN NaN    NaN    NaN
# 4        NaN NaN NaN NaN    NaN    NaN
# ...      ...  ..  ..  ..    ...    ...
# 82691    NaN NaN NaN NaN    NaN    NaN
# 82692    NaN NaN NaN NaN    NaN    NaN
# 82693    NaN NaN NaN NaN    NaN    NaN
# 82694    NaN NaN NaN NaN    NaN    NaN
# 82695    NaN NaN NaN NaN    NaN    NaN
#
# [82696 rows x 11 columns]

# %%
df_pin2 = pd.read_xml('lib.xml',xpath='//pin')
df_pin2
# Out:
#       name  voltage                          vector active_input active_ouput  \
# 0      VDD   0.7150         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 1      VPP   0.7150         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 2      VSS   0.0000         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 3      VBB   0.0000         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 4      VDD   0.7150         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# ...    ...      ...                             ...          ...          ...
# 82691  VSS   0.0000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
# 82692  VDD   0.7865  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
# 82693  VSS   0.0000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
# 82694  VDD   0.7865  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
# 82695  VSS   0.0000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1            Z
#
#        state  C1  C2   R  Slew1  Slew2
# 0        NaN NaN NaN NaN    NaN    NaN
# 1        NaN NaN NaN NaN    NaN    NaN
# 2        NaN NaN NaN NaN    NaN    NaN
# 3        NaN NaN NaN NaN    NaN    NaN
# 4        NaN NaN NaN NaN    NaN    NaN
# ...      ...  ..  ..  ..    ...    ...
# 82691    NaN NaN NaN NaN    NaN    NaN
# 82692    NaN NaN NaN NaN    NaN    NaN
# 82693    NaN NaN NaN NaN    NaN    NaN
# 82694    NaN NaN NaN NaN    NaN    NaN
# 82695    NaN NaN NaN NaN    NaN    NaN
#
# [82696 rows x 11 columns]

# %%
df_state = pd.read_xml('lib.xml',xpath='/lib/corner/view/cell/pin/state')
df_state
# Out:
#                           name  data
# 0        ADS_DEFAULT_STATE_LOW   NaN
# 1        ADS_DEFAULT_STATE_LOW   NaN
# 2        ADS_DEFAULT_STATE_LOW   NaN
# 3        ADS_DEFAULT_STATE_LOW   NaN
# 4       ADS_DEFAULT_STATE_HIGH   NaN
# ...                        ...   ...
# 180579  ADS_DEFAULT_STATE_HIGH   NaN
# 180580   ADS_DEFAULT_STATE_LOW   NaN
# 180581   ADS_DEFAULT_STATE_LOW   NaN
# 180582  ADS_DEFAULT_STATE_HIGH   NaN
# 180583  ADS_DEFAULT_STATE_HIGH   NaN
#
# [180584 rows x 2 columns]

# %%
df_cell_cap = pd.read_xml('lib.xml',xpath='/lib/corner/view[@name="CAP"]/cell')
df_cell_cap
# Out:
#                                           name  type  pin
# 0                 AN8ITLICMD1BWP169H3P45CPDLVT  None  NaN
# 1                 AN8ITLICMD2BWP169H3P45CPDLVT  None  NaN
# 2          AOI22RPEQAITLICMD1BWP169H3P45CPDLVT  None  NaN
# 3          AOI22RPEQBITLICMD1BWP169H3P45CPDLVT  None  NaN
# 4          AOI22RPEQCITLICMD1BWP169H3P45CPDLVT  None  NaN
# 5          AOI22RPEQDITLICMD1BWP169H3P45CPDLVT  None  NaN
# 6          CKBCUSDRMZITLICMD4BWP169H3P45CPDLVT  None  NaN
# 7   CKBDHDVGFEMM2P34ITLICMD18BWP169H3P45CPDLVT  None  NaN
# 8   CKBDHDVGFEMM2P34ITLICMD20BWP169H3P45CPDLVT  None  NaN
# 9   CKBTHDVGFEMM2P34ITLICMD24BWP169H3P45CPDLVT  None  NaN
# 10          CKLHQOPTQITLICMD3BWP169H3P45CPDLVT  None  NaN
# 11     CKNDHFEMM2P34ITLICMD18BWP169H3P45CPDLVT  None  NaN
# 12     CKNDHFEMM2P34ITLICMD20BWP169H3P45CPDLVT  None  NaN
# 13     CKNTHFEMM2P34ITLICMD24BWP169H3P45CPDLVT  None  NaN
# 14            CMPTRDHITLICMD2BWP169H3P45CPDLVT  None  NaN
# 15        LNWODCNQOPAITLICMD1BWP169H3P45CPDLVT  None  NaN
# 16             ND4EQAITLICMD2BWP169H3P45CPDLVT  None  NaN
# 17             ND4EQBITLICMD2BWP169H3P45CPDLVT  None  NaN
# 18             ND4EQCITLICMD2BWP169H3P45CPDLVT  None  NaN
# 19             ND4EQDITLICMD2BWP169H3P45CPDLVT  None  NaN
# 20                OR8ITLICMD1BWP169H3P45CPDLVT  None  NaN
# 21                OR8ITLICMD2BWP169H3P45CPDLVT  None  NaN

# %%
df_pin_cap = pd.read_xml('lib.xml',xpath='/lib/corner/view[@name="CAP"]//pin')
df_pin_cap
# Out:
#     name  voltage                          vector active_input active_ouput  \
# 0    VDD    0.715         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 1    VPP    0.715         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 2    VSS    0.000         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 3    VBB    0.000         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# 4    VDD    0.715         A1&A2&A3&A4&A5&A6&A7&A8           A1           A1
# ..   ...      ...                             ...          ...          ...
# 171  VBB    0.000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1           A1
# 172  VDD    0.715  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1           A1
# 173  VPP    0.715  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1           A1
# 174  VSS    0.000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1           A1
# 175  VBB    0.000  A1&!A2&!A3&!A4&!A5&!A6&!A7&!A8           A1           A1
#
#      state
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 171    NaN
# 172    NaN
# 173    NaN
# 174    NaN
# 175    NaN
#
# [176 rows x 6 columns]

# %%
df_cell_cap = pd.read_xml('lib.xml',xpath='/lib/corner/view[@name="CAP"]//pin[@name="VDD"]//data')
print(df_cell_cap)
# Out:
#      pin           esc       esr          leak
# 0    VDD  3.875020e-15  532.8700           NaN
# 1    VPP  1.658760e-16  169.6450           NaN
# 2    VSS  3.916560e-15  573.6790           NaN
# 3    VBB  4.386360e-16   93.8421           NaN
# 4    VDD           NaN       NaN  4.586640e-08
# ..   ...           ...       ...           ...
# 347  VBB  5.453750e-16   83.8936           NaN
# 348  VDD           NaN       NaN  5.822310e-08
# 349  VPP           NaN       NaN  1.572870e-11
# 350  VSS           NaN       NaN  5.820260e-08
# 351  VBB           NaN       NaN  3.617280e-11
#
# [352 rows x 4 columns]
