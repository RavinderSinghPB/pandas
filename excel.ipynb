# %%
import pandas as pd

# %%
df = pd.read_csv('demo_36r1h.csv')

# %%
df
# Out:
#     commonscripcode  Client_code  L4Client_Code                  cltname  \
# 0              9785          3.0           95.0  SURESH KISHANLAL MUNDRA
# 1              9785          3.0          101.0  SURESH KISHANLAL MUNDRA
# 2              9785          3.0            3.0  SURESH KISHANLAL MUNDRA
# 3              9785          3.0            4.0  SURESH KISHANLAL MUNDRA
# 4              9785          3.0         7548.0  SURESH KISHANLAL MUNDRA
# 5               329          3.0          101.0  SURESH KISHANLAL MUNDRA
# 6               329          3.0           95.0  SURESH KISHANLAL MUNDRA
# 7               329          3.0            4.0  SURESH KISHANLAL MUNDRA
# 8               329          3.0            3.0  SURESH KISHANLAL MUNDRA
# 9               731          3.0            3.0  SURESH KISHANLAL MUNDRA
# 10              778          3.0            3.0  SURESH KISHANLAL MUNDRA
# 11              985          3.0            3.0  SURESH KISHANLAL MUNDRA
# ...

# %%
df.to_excel('demo_36r1h.xlsx')

# %%
dfe = pd.read_excel('cent.xlsx')

# %%
dfe
# Out:
#     Unnamed: 0            Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0          NaN                   NaN         NaN         NaN         NaN
# 1          NaN  Capital Gains Report         NaN         NaN         NaN
# 2          NaN                   NaN         NaN         NaN         NaN
# 3          NaN                   NaN         NaN         NaN         NaN
# 4          NaN                   ABC       123.0       123.0       123.0
# 5          NaN                   ABC       123.0       123.0       123.0
# 6          NaN                   ABC       123.0       123.0       123.0
# 7          NaN                   ABC       123.0       123.0       123.0
# 8          NaN                   ABC       123.0       123.0       123.0
# 9          NaN                   ABC       123.0       123.0       123.0
# 10         NaN                   ABC       123.0       123.0       123.0
# 11         NaN                   ABC       123.0       123.0       123.0
# ...

# %%
dfe.to_csv('cent.csv')

# %%
dfec = pd.read_csv('cent.csv')

# %%
dfec.to_excel('csexcent.xlsx')

# %%
dfe.to_excel('xlt.xlsx', index=False)

# %%
df = pd.read_excel('cent.xlsx',header=None)

# %%
df.to_excel('xlt.xlsx', index=False,header=False)
